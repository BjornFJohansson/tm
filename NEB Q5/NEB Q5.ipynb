# %% [markdown]
# # Test of the NEB Tm Calculator ([tmcalculator.neb.com](https://tmcalculator.neb.com/#!/batch))

# %%
import csv
primerlist = []
with open('tmcalc_batch.txt', newline='') as csvfile:
    neb_file_reader = csv.reader(csvfile, delimiter='\t')
    for row in neb_file_reader:
        name, sequence, nebtm, *rest = row
        primerlist.append([name, sequence, nebtm])
print(len(primerlist))
# Out:
# 200

# %%
from Bio.SeqUtils import MeltingTemp as mt
from prettytable import PrettyTable
t = PrettyTable(['Name', 'Sequence', "neb", "bp"])
accdiff = 0

for name, primer, nebtm in primerlist:
    bptm = mt.Tm_NN(
        primer,
        nn_table=mt.DNA_NN3,
        Na=0,  # mM
        K=114.1533,  # mM
        Tris=0,  # mM
        Mg=2.0,
        dnac1=500,  # nM
        dnac2=0,  # nM
        dNTPs=0.8,  # mM
        saltcorr=7,
    ) 
    nebtm = int(nebtm)
    if nebtm != round(bptm):
        t.add_row([name, primer, nebtm, round(bptm, 4)])
    accdiff += nebtm - bptm
print(accdiff)
t
# Out:
# 3.66844918175957e-05
# +------+--------------------+-----+---------+
# | Name |      Sequence      | neb |    bp   |
# +------+--------------------+-----+---------+
# | ﻿p101 | AATTAATTTATGTATAAC |  41 |  41.519 |
# | p110 | AAAATAGACTTTATAAGT |  44 | 45.2502 |
# | p104 | TCCAAATTAATTTAGAAT |  45 | 46.2967 |
# | p26  | GTTTCAATTTTGTATTTA |  45 | 46.0531 |
# | p163 | ATTAGAATGATTCCAATT |  48 | 49.1392 |
# | p10  | TCATTATCATAAGGAGTA |  49 | 49.5418 |
# | p112 | TAAATACACAAAGATACC |  49 | 49.5137 |
# | p44  | TAATTTTTACCCCTATGA |  50 | 50.7655 |
# | p70  | GTTTTTATGTCGTTCTTA |  50 | 50.8067 |
# | p196 | GGAAATTAATTGCTAACT |  50 | 50.8708 |
# | p117 | GCTTATACGATAGATCTT |  51 | 51.5216 |
# | p125 | CATGAAACTCTAAACAAA |  50 | 51.0348 |
# | p49  | CGAGATGTTTATTCTTGA |  52 | 52.9357 |
# | p56  | AGATTAGAATGAAGACCA |  53 | 53.5486 |
# | p68  | ACAATTCAAATAGCAGTT |  52 | 53.1069 |
# | p179 | TAACGAATTTCGTTTCTT |  52 | 53.0707 |
# | p151 | GCTAGCAGATGAATACAA |  55 | 55.7231 |
# | p159 | AAACTCAGGATATTCGTG |  55 | 55.6433 |
# | p12  | TCTACCATGGGAGATATG |  56 | 56.5782 |
# | p20  | ATTCGTAGATGTCCAGAA |  56 | 56.6671 |
# | p67  | AAGACCTTCAAGGGATTA |  56 |  56.615 |
# | p184 | TGACTGAATATTGGGACT |  56 | 56.6637 |
# | p119 | GAATTTTGGTTTACCGCT |  57 | 57.5055 |
# | p136 | TGTACGCACGTATAGTAC |  57 | 57.6661 |
# | p89  | TGAACACTTATACGCTGT |  57 | 57.5452 |
# | p156 | CTATGGCAAATAGCTCCA |  58 | 58.5069 |
# | p65  | GGTGATTGCTTCCTTTTG |  58 | 58.5206 |
# | p11  | TTCACAAGTCGATTTGGG |  59 | 59.5043 |
# | p122 | TGGCATACTGATACCCTT |  59 | 59.5607 |
# | p54  | TCAACTCTTGACAGCGAT |  60 | 60.5763 |
# | p182 | AGCTTATATCAGCGCTCG |  61 | 61.5016 |
# | p146 | GGTTCAGCCACGTATACC |  63 | 62.3783 |
# | p103 | GGGGATTGCCCCTTAGTA |  64 | 63.4532 |
# | p158 | GGGACAGACTGCATTCCA |  65 | 64.4667 |
# | p111 | GACCTATGAGATCCCGGC |  65 | 64.3623 |
# | p109 | CAGCACGGTTACTAGGCC |  66 | 65.3485 |
# | p14  | GCTTGCACCTGCGCAATT |  68 | 67.4183 |
# | p187 | ATGACGGCCAGCATCGTT |  68 | 67.4367 |
# | p132 | AGTGCATCCGGTCAGTCG |  68 | 67.2983 |
# | p198 | TGGACCCCTGTCTCACGT |  69 | 68.2878 |
# | p99  | TTGCACACCCTTGAGGCC |  69 | 68.4512 |
# |  p7  | CTCACCTGGAGGTCCGGG |  71 | 70.0393 |
# | p164 | ACCTAAGGGAAGGGCGCC |  71 | 70.1769 |
# | p127 | CGGCTTACAGGCACGCGT |  72 | 71.3032 |
# | p128 | GGGCGCGCAGTCGGTTAA |  72 | 71.3781 |
# | p130 | GTGCTGTACGAGGGGCCC |  72 | 71.1756 |
# | p177 | TTCGGGCACAACCGAGGC |  72 | 71.2554 |
# | p88  | TCCCCGGGTCTGGTCACA |  72 | 71.2525 |
# | p98  | ATGCCGCGGTCCTGAACC |  72 | 71.0969 |
# |  p4  | GACGCCCCCCTACGGCTA |  73 | 72.1604 |
# | p129 | CTGCGACCCGCATCCAGC |  73 | 72.1851 |
# |  p5  | GGAGAGCGAGCGCGCTCA |  74 | 73.3451 |
# | p28  | GACCCCGTACGGGGGGTC |  74 | 73.1012 |
# | p78  | GTTAGCGCCCACCGGGCG |  76 | 75.0847 |
# | p31  | GCCAGGCTCCGCGTGCCG |  79 | 78.2019 |
# +------+--------------------+-----+---------+

# %%
from Bio.SeqUtils import MeltingTemp as mt
from prettytable import PrettyTable
t = PrettyTable(['Name', 'Sequence', "neb", "bp"])
accdiff = 0

for name, primer, nebtm in primerlist:
    bptm = mt.Tm_NN(
        primer,
        nn_table=mt.DNA_NN3,
        Na=0,  # mM
        K=212.223,  # mM
        Tris=0,  # mM
        Mg=2.0,
        dnac1=500,  # nM
        dnac2=0,  # nM
        dNTPs=0.8,  # mM
        saltcorr=1,
    ) 
    nebtm = int(nebtm)
    if nebtm != round(bptm):
        t.add_row([name, primer, nebtm, round(bptm, 4)])
    accdiff += nebtm - bptm
print(accdiff)
t
# Out:
# -0.002574895009672673
# +------+--------------------+-----+---------+
# | Name |      Sequence      | neb |    bp   |
# +------+--------------------+-----+---------+
# | ﻿p101 | AATTAATTTATGTATAAC |  41 |  42.924 |
# | p110 | AAAATAGACTTTATAAGT |  44 |  46.539 |
# | p104 | TCCAAATTAATTTAGAAT |  45 | 47.6456 |
# | p26  | GTTTCAATTTTGTATTTA |  45 |  47.388 |
# | p163 | ATTAGAATGATTCCAATT |  48 | 50.3078 |
# | p10  | TCATTATCATAAGGAGTA |  49 | 50.3884 |
# | p112 | TAAATACACAAAGATACC |  49 | 50.3588 |
# | p44  | TAATTTTTACCCCTATGA |  50 | 51.6779 |
# | p45  | TATCGATTATCTCTAAGG |  50 |  51.028 |
# | p70  | GTTTTTATGTCGTTCTTA |  50 | 51.7214 |
# | p173 | TACTAAACAGATAACTGT |  50 | 51.2677 |
# | p196 | GGAAATTAATTGCTAACT |  50 | 51.7889 |
# | p117 | GCTTATACGATAGATCTT |  51 | 52.1267 |
# | p125 | CATGAAACTCTAAACAAA |  50 | 51.9618 |
# | p84  | TACGGTAGATTGTTTAAA |  51 | 52.3751 |
# | p141 | GATAAAGCCTTAACCTTA |  52 | 52.8815 |
# | p142 | AATACAGTCTGCTACTTA |  53 | 53.9027 |
# | p49  | CGAGATGTTTATTCTTGA |  52 | 53.6142 |
# | p154 | TTTATGTTACAACGAGAC |  53 | 53.8525 |
# | p56  | AGATTAGAATGAAGACCA |  53 | 54.2591 |
# | p68  | ACAATTCAAATAGCAGTT |  52 |  54.146 |
# | p179 | TAACGAATTTCGTTTCTT |  52 | 54.1078 |
# | p180 | GTTCAATTACACCCTTAA |  53 | 53.8023 |
# | p114 | AAGACTAGACGTCTTATG |  54 |  54.695 |
# | p138 | GTTAAGAGACTATCGACA |  54 | 54.6884 |
# | p61  | TACGTTTATGAAAATGCC |  54 | 55.0061 |
# | p71  | AAAATAACGGCACATAAG |  54 | 55.0136 |
# | p200 | TAAACCATAATCACGACT |  54 | 54.9862 |
# | p166 | GTGTTTTGAGTTGTATGG |  55 | 55.5613 |
# | p199 | ACAACTAAGACTCTAGGA |  55 | 55.6291 |
# | p149 | GATTGATCCATGAATGGT |  56 | 56.5908 |
# | p151 | GCTAGCAGATGAATACAA |  55 | 56.1907 |
# | p159 | AAACTCAGGATATTCGTG |  55 | 56.1069 |
# | p161 | ACACAACATTGCTGTTAA |  56 | 57.2139 |
# | p12  | TCTACCATGGGAGATATG |  56 |  56.731 |
# | p113 | GGCTTTTAGACAAACGTA |  56 | 56.9674 |
# | p20  | ATTCGTAGATGTCCAGAA |  56 | 57.1822 |
# | p64  | ATTGTATACTGAAGCGGA |  57 | 57.5871 |
# | p67  | AAGACCTTCAAGGGATTA |  56 | 57.1275 |
# | p184 | TGACTGAATATTGGGACT |  56 | 57.1787 |
# | p119 | GAATTTTGGTTTACCGCT |  57 |  58.063 |
# | p136 | TGTACGCACGTATAGTAC |  57 | 57.8714 |
# | p66  | CCGATTACGTAAATCTGC |  57 | 57.5883 |
# | p89  | TGAACACTTATACGCTGT |  57 | 58.1047 |
# | p96  | TACTAGTCTCGACCAGTA |  57 | 57.5285 |
# | p139 | CGGTATGTATTGCTGCTA |  58 | 58.7114 |
# | p156 | CTATGGCAAATAGCTCCA |  58 | 58.7529 |
# | p65  | GGTGATTGCTTCCTTTTG |  58 | 58.7673 |
# | p11  | TTCACAAGTCGATTTGGG |  59 | 59.7988 |
# | p122 | TGGCATACTGATACCCTT |  59 | 59.8579 |
# | p50  | CATCGTCTCTGAAGAACG |  60 | 59.4809 |
# | p160 | AATGCTATACTTCGCCCT |  60 | 60.5701 |
# | p54  | TCAACTCTTGACAGCGAT |  60 |  60.923 |
# | p77  | TCGTGAGGTTCAACGTAA |  60 | 60.7638 |
# | p92  | TAGCTCAATGTGACAGCT |  60 | 60.6809 |
# | p182 | AGCTTATATCAGCGCTCG |  61 | 61.5254 |
# |  p3  | GGCATACCACTCTAGAGC |  62 | 61.1921 |
# | p118 | GCTATGACAGGGGTTAGG |  62 | 61.2307 |
# | p146 | GGTTCAGCCACGTATACC |  63 |  62.074 |
# | p76  | AAGATTTGCCTATCCGCG |  62 | 62.5009 |
# | p79  | GGGACTCAATCATGGTGG |  63 | 62.2039 |
# | p103 | GGGGATTGCCCCTTAGTA |  64 | 63.1968 |
# | p126 | CTAAGGGTGGTTCTTCGC |  63 | 62.3328 |
# | p43  | CCAGCTGACTCTAAAGCG |  63 | 62.3015 |
# | p155 | GAATGGCTTCCCAGAGTG |  63 | 62.4573 |
# | p165 | CGCCTACTCTGAACGTTG |  63 | 62.4885 |
# | p95  | CCTCCGTTAGATAGCCCT |  63 | 62.4238 |
# | p137 | GCGTAGTGCTACCGTACT |  64 | 63.3765 |
# | p52  | TTATAGTGAGCCGAGGGC |  64 | 63.3509 |
# | p158 | GGGACAGACTGCATTCCA |  65 | 64.2557 |
# | p167 | ATTCCTCGCTATGTCGGC |  65 | 64.2911 |
# | p73  | ACGTGATACACCGGCTAG |  64 | 63.4805 |
# | p178 | GACTGGAGAGACAGCTCC |  64 | 63.4933 |
# | p111 | GACCTATGAGATCCCGGC |  65 | 63.7737 |
# | p21  | TCATGGCTTCTCACGGTG |  65 | 64.4547 |
# | p150 | TAACGTGTGGCGCTATCC |  65 |  64.448 |
# | p153 | CCGCCTATCCCTGACAAG |  65 | 64.3196 |
# | p162 | GCAGAACACCGATGCCTT |  66 | 65.4683 |
# | p194 | CTCCCGCTCATAGCTTCC |  65 | 64.3259 |
# | p109 | CAGCACGGTTACTAGGCC |  66 | 64.8019 |
# | p23  | CCTCCCCATATACCGCCT |  66 | 65.4948 |
# | p106 | CCCTGCCGGCAATACAAC |  67 |  66.199 |
# | p14  | GCTTGCACCTGCGCAATT |  68 | 67.3403 |
# | p123 | GCAGCAAGTCGTCACGTG |  67 | 66.2903 |
# | p187 | ATGACGGCCAGCATCGTT |  68 | 67.3595 |
# | p24  | GCGGATGCCCTAATCGCT |  68 | 67.4842 |
# | p132 | AGTGCATCCGGTCAGTCG |  68 | 66.8353 |
# | p58  | CCTTAGGGCTCCACACCG |  68 | 67.0482 |
# | p93  | GGTCAGGCTAGGAGCTCC |  67 | 66.1811 |
# | p198 | TGGACCCCTGTCTCACGT |  69 | 67.8674 |
# | p25  | ATGGGCAACCCCTACCCT |  69 | 68.4928 |
# | p30  | CCAGGGTTGCCTTGGCAA |  69 | 68.4709 |
# | p91  | AGCGCCATTTGGGTGAGG |  69 | 68.1068 |
# | p99  | TTGCACACCCTTGAGGCC |  69 | 68.0378 |
# | p19  | GGAGCTGACGCTCCCAGA |  70 | 68.8033 |
# | p60  | GGACCTCCCCCTGCAACT |  70 | 69.1628 |
# | p186 | AACCGACCTGCCCTCCTG |  70 | 69.2755 |
# |  p7  | CTCACCTGGAGGTCCGGG |  71 | 68.9254 |
# | p145 | TGCTACACGTCGCCGGTG |  71 | 69.9239 |
# | p48  | ATGCATGGCCGAGGTGCA |  71 | 70.3481 |
# | p164 | ACCTAAGGGAAGGGCGCC |  71 | 69.4528 |
# | p183 | ACGAGACGCGCGACACAC |  71 | 70.2078 |
# | p127 | CGGCTTACAGGCACGCGT |  72 | 70.6254 |
# | p128 | GGGCGCGCAGTCGGTTAA |  72 | 70.7034 |
# | p130 | GTGCTGTACGAGGGGCCC |  72 | 70.1058 |
# | p177 | TTCGGGCACAACCGAGGC |  72 | 70.5757 |
# | p88  | TCCCCGGGTCTGGTCACA |  72 | 70.5726 |
# | p98  | ATGCCGCGGTCCTGAACC |  72 | 70.4106 |
# |  p4  | GACGCCCCCCTACGGCTA |  73 | 71.1289 |
# | p15  | AGCCCCCCAGTGCCCTTT |  73 | 72.3407 |
# | p129 | CTGCGACCCGCATCCAGC |  73 | 71.1546 |
# |  p5  | GGAGAGCGAGCGCGCTCA |  74 | 72.3599 |
# | p28  | GACCCCGTACGGGGGGTC |  74 | 71.7161 |
# | p143 | GGGCAGGAGGGTGGTCCA |  73 |  71.749 |
# | p51  | TCCTCGGCCCGTGCCTCT |  75 | 73.6471 |
# | p78  | GTTAGCGCCCACCGGGCG |  76 | 73.7729 |
# | p22  | CGCGTGTCATGGCCGGCG |  76 | 74.3165 |
# | p31  | GCCAGGCTCCGCGTGCCG |  79 | 76.6048 |
# +------+--------------------+-----+---------+
